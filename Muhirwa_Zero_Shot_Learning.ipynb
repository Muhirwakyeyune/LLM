# %% [markdown]
# **Agenda**:
# 1. What is Zero-Shot Learning or Zero-shot classification?
# 2. How zero shot learning models work?
# 3. Zero-shot classification using HuggingFace Transformers

# %% [markdown]
# **How does Zero-Shot Learning work?** <br>
# Zero-shot learning is when we are testing a model on a task for which it hasn't been trained.
#
# In **Zero-shot classification** we are asking the model to do classification for labels which model hasn't seen during the model.

# %% [markdown]
# One of the popular methods for zero-shot learning is **Natural Language Inference** (NLI).<br>
#
# *Natural language inference* is the task of determining whether a “hypothesis” is true (entailment), false (contradiction), or undetermined (neutral) given a “premise”.

# %%
# !pip install -q transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 45.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 16.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 68.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 45.4 MB/s eta 0:00:00

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
sequence_to_classify = "I love her so much, she  is beatiful. she loves me too. we will be at paris for our love"
candidate_labels = ['travel', 'dating', 'dancing']

classifier(sequence_to_classify, candidate_labels)
# Out:
# {'sequence': 'I love her so much, she  is beatiful. she loves me too. we will be at paris for our love',
#  'labels': ['dating', 'travel', 'dancing'],
#  'scores': [0.5268855690956116, 0.45149853825569153, 0.021615926176309586]}

# %% [markdown]
# **If more than one candidate label can be correct.**

# %%
candidate_labels = ['travel', 'cooking', 'dancing', 'exploration', 'Love']
classifier(sequence_to_classify, candidate_labels, multi_label=True)
# Out:
# {'sequence': 'I love her so much, she  is beatiful. she loves me too. we will be at paris for our love',
#  'labels': ['Love', 'travel', 'exploration', 'dancing', 'cooking'],
#  'scores': [0.9696177840232849,
#   0.9653202891349792,
#   0.3541734516620636,
#   0.16125865280628204,
#   0.05128549411892891]}

# %%
sequence_to_classify = "Paul Kagame will be next president. He will develop Sport in Rwanda"
candidate_labels = ['science', 'politics', 'history','Football']

classifier(sequence_to_classify, candidate_labels)
# Out:
# {'sequence': 'Paul Kagame will be next president. He will develop Sport in Rwanda',
#  'labels': ['politics', 'history', 'Football', 'science'],
#  'scores': [0.6415064930915833,
#   0.23026561737060547,
#   0.08713028579950333,
#   0.04109759256243706]}
